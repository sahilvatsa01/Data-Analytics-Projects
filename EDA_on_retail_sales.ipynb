# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('menu.csv')
print(df.head())
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 0                             25        0.0  ...             31
# 1                             15        0.0  ...             30
# 2                             42        0.0  ...             29
# 3                             52        0.0  ...             30
# 4                             42        0.0  ...             30
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
# 2                             10              4
# 3                             10              4
# 4                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# 1                             17       3       18                          6
# 2                             17       2       14                          8
# 3                             17       2       21                         15
# 4                             17       2       21                          6
#
#    Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 0                          0                       25                    15
# 1                          0                       25                     8
# 2                          0                       25                    10
# 3                          0                       30                    15
# 4                          0                       25                    10
#
# [5 rows x 24 columns]

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
#  12  Sodium                         260 non-null    int64
#  13  Sodium (% Daily Value)         260 non-null    int64
#  14  Carbohydrates                  260 non-null    int64
#  15  Carbohydrates (% Daily Value)  260 non-null    int64
#  16  Dietary Fiber                  260 non-null    int64
#  17  Dietary Fiber (% Daily Value)  260 non-null    int64
#  18  Sugars                         260 non-null    int64
#  19  Protein                        260 non-null    int64
#  20  Vitamin A (% Daily Value)      260 non-null    int64
#  21  Vitamin C (% Daily Value)      260 non-null    int64
#  22  Calcium (% Daily Value)        260 non-null    int64
#  23  Iron (% Daily Value)           260 non-null    int64
# dtypes: float64(3), int64(18), object(3)
# memory usage: 48.9+ KB
# None

# %%
df.describe(include='all')
# Out:
#             Category          Item  Serving Size     Calories  \
# count            260           260           260   260.000000
# unique             9           260           107          NaN
# top     Coffee & Tea  Egg McMuffin  16 fl oz cup          NaN
# freq              95             1            45          NaN
# mean             NaN           NaN           NaN   368.269231
# std              NaN           NaN           NaN   240.269886
# min              NaN           NaN           NaN     0.000000
# 25%              NaN           NaN           NaN   210.000000
# 50%              NaN           NaN           NaN   340.000000
# 75%              NaN           NaN           NaN   500.000000
# max              NaN           NaN           NaN  1880.000000
#
#         Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count          260.000000  260.000000                 260.000000
# unique                NaN         NaN                        NaN
# top                   NaN         NaN                        NaN
# freq                  NaN         NaN                        NaN
# mean           127.096154   14.165385                  21.815385
# std            127.875914   14.205998                  21.885199
# min              0.000000    0.000000                   0.000000
# 25%             20.000000    2.375000                   3.750000
# 50%            100.000000   11.000000                  17.000000
# 75%            200.000000   22.250000                  35.000000
# max           1060.000000  118.000000                 182.000000
#
#         Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  ...  \
# count      260.000000                     260.000000  260.000000  ...
# unique            NaN                            NaN         NaN  ...
# top               NaN                            NaN         NaN  ...
# freq              NaN                            NaN         NaN  ...
# mean         6.007692                      29.965385    0.203846  ...
# std          5.321873                      26.639209    0.429133  ...
# min          0.000000                       0.000000    0.000000  ...
# 25%          1.000000                       4.750000    0.000000  ...
# 50%          5.000000                      24.000000    0.000000  ...
# 75%         10.000000                      48.000000    0.000000  ...
# max         20.000000                     102.000000    2.500000  ...
#
#         Carbohydrates  Carbohydrates (% Daily Value)  Dietary Fiber  \
# count      260.000000                     260.000000     260.000000
# unique            NaN                            NaN            NaN
# top               NaN                            NaN            NaN
# freq              NaN                            NaN            NaN
# mean        47.346154                      15.780769       1.630769
# std         28.252232                       9.419544       1.567717
# min          0.000000                       0.000000       0.000000
# 25%         30.000000                      10.000000       0.000000
# 50%         44.000000                      15.000000       1.000000
# 75%         60.000000                      20.000000       3.000000
# max        141.000000                      47.000000       7.000000
#
#         Dietary Fiber (% Daily Value)      Sugars     Protein  \
# count                      260.000000  260.000000  260.000000
# unique                            NaN         NaN         NaN
# top                               NaN         NaN         NaN
# freq                              NaN         NaN         NaN
# mean                         6.530769   29.423077   13.338462
# std                          6.307057   28.679797   11.426146
# min                          0.000000    0.000000    0.000000
# 25%                          0.000000    5.750000    4.000000
# 50%                          5.000000   17.500000   12.000000
# 75%                         10.000000   48.000000   19.000000
# max                         28.000000  128.000000   87.000000
#
#         Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# count                  260.000000                 260.000000
# unique                        NaN                        NaN
# top                           NaN                        NaN
# freq                          NaN                        NaN
# mean                    13.426923                   8.534615
# std                     24.366381                  26.345542
# min                      0.000000                   0.000000
# 25%                      2.000000                   0.000000
# 50%                      8.000000                   0.000000
# 75%                     15.000000                   4.000000
# max                    170.000000                 240.000000
#
#         Calcium (% Daily Value)  Iron (% Daily Value)
# count                260.000000            260.000000
# unique                      NaN                   NaN
# top                         NaN                   NaN
# freq                        NaN                   NaN
# mean                  20.973077              7.734615
# std                   17.019953              8.723263
# min                    0.000000              0.000000
# 25%                    6.000000              0.000000
# 50%                   20.000000              4.000000
# 75%                   30.000000             15.000000
# max                   70.000000             40.000000
#
# [11 rows x 24 columns]

# %%
max_values= df[['Calories','Total Fat','Carbohydrates','Dietary Fiber','Sugars','Protein','Vitamin A (% Daily Value)','Vitamin C (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)']].max()
print(max_values)
# Out:
# Calories                     1880.0
# Total Fat                     118.0
# Carbohydrates                 141.0
# Dietary Fiber                   7.0
# Sugars                        128.0
# Protein                        87.0
# Vitamin A (% Daily Value)     170.0
# Vitamin C (% Daily Value)     240.0
# Calcium (% Daily Value)        70.0
# Iron (% Daily Value)           40.0
# dtype: float64

# %%
f = plt.figure(figsize=(19,15))
corr_matrix = df.select_dtypes(['number']).corr()
plt.matshow(corr_matrix)

plt.xticks(range(corr_matrix.shape[1]), corr_matrix.columns, fontsize=12, rotation=90)
plt.yticks(range(corr_matrix.shape[1]), corr_matrix.columns, fontsize=12)


cb = plt.colorbar()
cb.ax.tick_params(labelsize=12)


plt.title('Correlation Matrix', fontsize=16)


plt.show()

# %%
sns.boxplot(x = df['Calories'],y = df['Category'],hue = df['Category'],palette = 'Set2')
# Out:
# <Axes: xlabel='Calories', ylabel='Category'>

# %%
plot=sns.set_style("whitegrid")
ax=sns.boxplot(x=df["Calories"])

# %%
df['Calories'].idxmax()
# Out:
# 82

# %%
df.at[82, 'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
plot=sns.stripplot(x="Category",y='Sodium',data=df)
plt.setp(plot.get_xticklabels(),rotation=70)
plt.title('Sodium Content')
plt.show()

plot=sns.jointplot(x="Protein",y='Total Fat', data=df)
plot=sns.jointplot(x="Protein",y='Calories',data=df)
plot=sns.jointplot(x="Carbohydrates",y='Calories', data=df)
plot=sns.jointplot(x="Cholesterol", y='Calories', data=df)
plot=sns.jointplot(x="Total Fat", y='Calories', data=df)
plot=sns.jointplot(x="Sugars", y='Calories', data=df)
plot=sns.jointplot(x="Dietary Fiber", y='Calories', data=df)
plot=sns.jointplot(x="Trans Fat", y='Calories', data=df)
plot=sns.jointplot(x="Vitamin A (% Daily Value)", y='Calories', data=df)
plot=sns.jointplot(x="Calcium (% Daily Value)", y='Calories', data=df)
plot=sns.jointplot(x="Iron (% Daily Value)", y='Calories', data=df)

# %%
df['Sodium'].idxmax()
# Out:
# 82

# %%
df.at[82,'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
df['Total Fat'].idxmax()
# Out:
# 82

# %%
df.at[82,'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
df['Sugars'].idxmax()
# Out:
# 253

# %%
df.at[253,'Item']
# Out:
# 'McFlurry with M&M’s Candies (Medium)'

# %%
df['Dietary Fiber'].idxmax()
# Out:
# 32

# %%
df.at[32,'Item']
# Out:
# 'Big Breakfast with Hotcakes (Large Biscuit)'

# %%
df['Trans Fat'].idxmax()
# Out:
# 47

# %%
df.at[47,'Item']
# Out:
# 'Double Quarter Pounder with Cheese'

# %%
df['Vitamin A (% Daily Value)'].idxmax()
# Out:
# 84

# %%
df.at[84,'Item']
# Out:
# 'Premium Bacon Ranch Salad (without Chicken)'

# %%
df['Calcium (% Daily Value)'].idxmax()
# Out:
# 246

# %%
df.at[246, 'Item']
# Out:
# 'Strawberry Shake (Large)'

# %%
df['Iron (% Daily Value)'].idxmax()
# Out:
# 31

# %%
df.at[31, 'Item']
# Out:
# 'Big Breakfast with Hotcakes (Regular Biscuit)'

# %%
lists=["Chicken & Fish","Breakfast","Smoothies & Shakes","Beef & Pork","Snacks & Sides","Desserts","Beverages"]

# %%
for list in lists:

    items=df.query('Category == list').sort_values(by="Calories", ascending=False)
    items_custom=items.iloc[:,[1,3,5]]

    items_t=df.query('Category == list').sort_values(by="Calories", ascending=True)
    items_custom_t=items_t.iloc[:,[1,3,5]]

    print(lists.index(list)+1,".",list)

    p_express = px.scatter(items_custom, x="Total Fat",y='Calories', color="Item",size='Calories',template="plotly_dark",hover_name="Item")
    p_express.show()


    table=items_custom.iloc[:,[0,1]].sort_values(by="Calories", ascending=False).style.hide(axis="index")
    display(table)

    fig,ax=plt.subplots()
    x=items_custom_t.iloc[:,0]
    y=items_custom_t.iloc[:,1]
    ax.barh(x,y, tick_label=x)
    plt.show()
# Out:
# 1 . Chicken & Fish
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5cb19eb5-290c-4258-8ecb-0c93d2ef6013" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5cb19eb5-290c-4258-8ecb-0c93d2ef6013")) {                    Plotly.newPlot(                        "5cb19eb5-290c-4258-8ecb-0c93d2ef6013",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Chicken McNuggets (40 piece)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Chicken McNuggets (40 piece)"],"legendgroup":"Chicken McNuggets (40 piece)","marker":{"color":"#636efa","size":[1880],"sizemode":"area","sizeref":4.7,"symbol":"circle"},"mode":"markers","name":"Chicken McNuggets (40 piece)","orientation":"v","showlegend":true,"x":[118.0],"xaxis":"x","y":[1880],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Chicken McNuggets (20 piece)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Chicken McNuggets (20 piece)"],"legendgroup":"Chicken McNuggets (20 piece)","marker":{"color":"#EF553B","size":[940],"sizemode":"area","sizeref":4.7,"symbol":"circle"},"mode":"markers","name":"Chicken McNuggets (20 piece)","orientation":"v","showlegend":true,"x":[59.0],"xaxis":"x","y":[940],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Bacon Clubhouse Crispy Chicken Sandwich\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Bacon Clubhouse Crispy Chicken Sandwich"],"legendgroup":"Bacon Clubhouse Crispy Chicken Sandwich","marker":{"color":"#00cc96","size":[750],"sizemode":"area","sizeref":4.7,"symbol":"circle"},"mode":"markers","name":"Bacon Clubhouse Crispy Chicken Sandwich","orientation":"v","showlegend":true,"x":[38.0],"xaxis":"x","y":[750],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Premium Crispy Chicken Club Sandwich\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Premium Crispy Chicken Club Sandwich"],"legendgroup":"Premium Crispy Chicken Club Sandwich","marker":{"color":"#ab63fa","size":[670],"sizemode":"area","sizeref":4.7,"symbol":"circle"},"mode":"markers","name":"Premium Crispy Chicken Club Sandwich","orientation":"v","showlegend":true,"x":[33.0],"xaxis":"x","y":[670],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Premium McWrap Southwest Chicken (Crispy Chicken)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Premium McWrap Southwest Chicken (Crispy Chicken)"],"legendgroup":"Premium McWrap Southwest Chicken (Crispy Chicken)","marker":{"color":"#FFA15A","size":[670],"sizemode":"area","sizeref":4.7,"symbol":"circle"},"mode":"markers","name":"Premium McWrap Southwest Chicken (Crispy Chicken)","orientation":"v","showlegend":true,"x":[33.0],"xaxis":"x","y":[670],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Premium McWrap Chicken & Bacon (Crispy Chicken)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Premium McWrap Chicken & Bacon (Crispy Chicken)"],"legendgroup":"Premium McWrap Chicken & Bacon (Crispy Chicken)","marker":{"color":"#19d3f3","size":[630],"sizemode":"area","sizere ...
# <style type="text/css">
# </style>
# <table id="T_3816d" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_3816d_level0_col0" class="col_heading level0 col0" >Item</th>
#       <th id="T_3816d_level0_col1" class="col_heading level0 col1" >Calories</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3816d_row0_col0" class="data row0 col0" >Chicken McNuggets (40 piece)</td>
#       <td id="T_3816d_row0_col1" class="data row0 col1" >1880</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row1_col0" class="data row1 col0" >Chicken McNuggets (20 piece)</td>
#       <td id="T_3816d_row1_col1" class="data row1 col1" >940</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row2_col0" class="data row2 col0" >Bacon Clubhouse Crispy Chicken Sandwich</td>
#       <td id="T_3816d_row2_col1" class="data row2 col1" >750</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row3_col0" class="data row3 col0" >Premium Crispy Chicken Club Sandwich</td>
#       <td id="T_3816d_row3_col1" class="data row3 col1" >670</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row4_col0" class="data row4 col0" >Premium McWrap Southwest Chicken (Crispy Chicken)</td>
#       <td id="T_3816d_row4_col1" class="data row4 col1" >670</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row5_col0" class="data row5 col0" >Premium McWrap Chicken & Bacon (Crispy Chicken)</td>
#       <td id="T_3816d_row5_col1" class="data row5 col1" >630</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row6_col0" class="data row6 col0" >Premium McWrap Chicken & Ranch (Crispy Chicken)</td>
#       <td id="T_3816d_row6_col1" class="data row6 col1" >610</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row7_col0" class="data row7 col0" >Premium Crispy Chicken Ranch BLT Sandwich</td>
#       <td id="T_3816d_row7_col1" class="data row7 col1" >610</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row8_col0" class="data row8 col0" >Bacon Clubhouse Grilled Chicken Sandwich</td>
#       <td id="T_3816d_row8_col1" class="data row8 col1" >590</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row9_col0" class="data row9 col0" >Premium McWrap Chicken Sweet Chili (Crispy Chicken)</td>
#       <td id="T_3816d_row9_col1" class="data row9 col1" >540</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row10_col0" class="data row10 col0" >Premium McWrap Southwest Chicken (Grilled Chicken)</td>
#       <td id="T_3816d_row10_col1" class="data row10 col1" >520</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row11_col0" class="data row11 col0" >Premium Crispy Chicken Classic Sandwich</td>
#       <td id="T_3816d_row11_col1" class="data row11 col1" >510</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row12_col0" class="data row12 col0" >Premium Grilled Chicken Club Sandwich</td>
#       <td id="T_3816d_row12_col1" class="data row12 col1" >510</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row13_col0" class="data row13 col0" >Bacon Cheddar McChicken</td>
#       <td id="T_3816d_row13_col1" class="data row13 col1" >480</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row14_col0" class="data row14 col0" >Premium McWrap Chicken & Bacon (Grilled Chicken)</td>
#       <td id="T_3816d_row14_col1" class="data row14 col1" >480</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row15_col0" class="data row15 col0" >Chicken McNuggets (10 piece)</td>
#       <td id="T_3816d_row15_col1" class="data row15 col1" >470</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row16_col0" class="data row16 col0" >Premium McWrap Chicken & Ranch (Grilled Chicken)</td>
#       <td id="T_3816d_row16_col1" class="data row16 col1" >450</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row17_col0" class="data row17 col0" >Premium Grilled Chicken Ranch BLT Sandwich</td>
#       <td id="T_3816d_row17_col1" class="data row17 col1" >450</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row18_col0" class="data row18 col0" >Bacon Buffalo Ranch McChicken</td>
#       <td id="T_3816d_row18_col1" class="data row18 col1" >430</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row19_col0" class="data row19 col0" >Southern Style Crispy Chicken Sandwich</td>
#       <td id="T_3816d_row19_col1" class="data row19 col1" >430</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row20_col0" class="data row20 col0" >Filet-O-Fish</td>
#       <td id="T_3816d_row20_col1" class="data row20 col1" >390</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row21_col0" class="data row21 col0" >Premium McWrap Chicken Sweet Chili (Grilled Chicken)</td>
#       <td id="T_3816d_row21_col1" class="data row21 col1" >380</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row22_col0" class="data row22 col0" >Buffalo Ranch McChicken</td>
#       <td id="T_3816d_row22_col1" class="data row22 col1" >360</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row23_col0" class="data row23 col0" >McChicken</td>
#       <td id="T_3816d_row23_col1" class="data row23 col1" >360</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row24_col0" class="data row24 col0" >Premium Grilled Chicken Classic Sandwich</td>
#       <td id="T_3816d_row24_col1" class="data row24 col1" >350</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row25_col0" class="data row25 col0" >Chicken McNuggets (6 piece)</td>
#       <td id="T_3816d_row25_col1" class="data row25 col1" >280</td>
#     </tr>
#     <tr>
#       <td id="T_3816d_row26_col0" class="data row26 col0" >Chicken McNuggets (4 piece)</td>
#       <td id="T_3816d_row26_col1" class="data row26 col1" >190</td>
#     </tr>
#   </tbody>
# </table>
# 2 . Breakfast
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1fb9db38-6287-49cc-b64f-6521eb7e2c1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fb9db38-6287-49cc-b64f-6521eb7e2c1d")) {                    Plotly.newPlot(                        "1fb9db38-6287-49cc-b64f-6521eb7e2c1d",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Big Breakfast with Hotcakes (Large Biscuit)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Big Breakfast with Hotcakes (Large Biscuit)"],"legendgroup":"Big Breakfast with Hotcakes (Large Biscuit)","marker":{"color":"#636efa","size":[1150],"sizemode":"area","sizeref":2.875,"symbol":"circle"},"mode":"markers","name":"Big Breakfast with Hotcakes (Large Biscuit)","orientation":"v","showlegend":true,"x":[60.0],"xaxis":"x","y":[1150],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Big Breakfast with Hotcakes (Regular Biscuit)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Big Breakfast with Hotcakes (Regular Biscuit)"],"legendgroup":"Big Breakfast with Hotcakes (Regular Biscuit)","marker":{"color":"#EF553B","size":[1090],"sizemode":"area","sizeref":2.875,"symbol":"circle"},"mode":"markers","name":"Big Breakfast with Hotcakes (Regular Biscuit)","orientation":"v","showlegend":true,"x":[56.0],"xaxis":"x","y":[1090],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)"],"legendgroup":"Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)","marker":{"color":"#00cc96","size":[1050],"sizemode":"area","sizeref":2.875,"symbol":"circle"},"mode":"markers","name":"Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)","orientation":"v","showlegend":true,"x":[50.0],"xaxis":"x","y":[1050],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)"],"legendgroup":"Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)","marker":{"color":"#ab63fa","size":[990],"sizemode":"area","sizeref":2.875,"symbol":"circle"},"mode":"markers","name":"Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)","orientation":"v","showlegend":true,"x":[46.0],"xaxis":"x","y":[990],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Big Breakfast (Large Biscuit)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Big Breakfast (Large Biscuit)"],"legendgroup":"Big Breakfast (Large Biscuit)","marker":{"color":"#FFA15A","size":[800],"sizemode":"area","sizeref":2.875,"symbol":"circle"},"mode":"markers","name":"Big Breakfast (Large Biscuit)","orientation":"v","showlegend":true,"x":[52.0],"xaxis":"x","y":[800],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Big Breakfast (Regular Biscuit)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u ...
# <style type="text/css">
# </style>
# <table id="T_990ca" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_990ca_level0_col0" class="col_heading level0 col0" >Item</th>
#       <th id="T_990ca_level0_col1" class="col_heading level0 col1" >Calories</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_990ca_row0_col0" class="data row0 col0" >Big Breakfast with Hotcakes (Large Biscuit)</td>
#       <td id="T_990ca_row0_col1" class="data row0 col1" >1150</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row1_col0" class="data row1 col0" >Big Breakfast with Hotcakes (Regular Biscuit)</td>
#       <td id="T_990ca_row1_col1" class="data row1 col1" >1090</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row2_col0" class="data row2 col0" >Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)</td>
#       <td id="T_990ca_row2_col1" class="data row2 col1" >1050</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row3_col0" class="data row3 col0" >Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)</td>
#       <td id="T_990ca_row3_col1" class="data row3 col1" >990</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row4_col0" class="data row4 col0" >Big Breakfast (Large Biscuit)</td>
#       <td id="T_990ca_row4_col1" class="data row4 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row5_col0" class="data row5 col0" >Big Breakfast (Regular Biscuit)</td>
#       <td id="T_990ca_row5_col1" class="data row5 col1" >740</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row6_col0" class="data row6 col0" >Big Breakfast with Egg Whites (Large Biscuit)</td>
#       <td id="T_990ca_row6_col1" class="data row6 col1" >690</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row7_col0" class="data row7 col0" >Steak, Egg & Cheese Bagel</td>
#       <td id="T_990ca_row7_col1" class="data row7 col1" >670</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row8_col0" class="data row8 col0" >Big Breakfast with Egg Whites (Regular Biscuit)</td>
#       <td id="T_990ca_row8_col1" class="data row8 col1" >640</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row9_col0" class="data row9 col0" >Bacon, Egg & Cheese Bagel</td>
#       <td id="T_990ca_row9_col1" class="data row9 col1" >620</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row10_col0" class="data row10 col0" >Sausage Biscuit with Egg (Large Biscuit)</td>
#       <td id="T_990ca_row10_col1" class="data row10 col1" >570</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row11_col0" class="data row11 col0" >Bacon, Egg & Cheese Bagel with Egg Whites</td>
#       <td id="T_990ca_row11_col1" class="data row11 col1" >570</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row12_col0" class="data row12 col0" >Sausage, Egg & Cheese McGriddles</td>
#       <td id="T_990ca_row12_col1" class="data row12 col1" >550</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row13_col0" class="data row13 col0" >Steak & Egg Biscuit (Regular Biscuit)</td>
#       <td id="T_990ca_row13_col1" class="data row13 col1" >540</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row14_col0" class="data row14 col0" >Sausage Biscuit with Egg Whites (Large Biscuit)</td>
#       <td id="T_990ca_row14_col1" class="data row14 col1" >520</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row15_col0" class="data row15 col0" >Hotcakes and Sausage</td>
#       <td id="T_990ca_row15_col1" class="data row15 col1" >520</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row16_col0" class="data row16 col0" >Bacon, Egg & Cheese Biscuit (Large Biscuit)</td>
#       <td id="T_990ca_row16_col1" class="data row16 col1" >520</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row17_col0" class="data row17 col0" >Sausage Biscuit with Egg (Regular Biscuit)</td>
#       <td id="T_990ca_row17_col1" class="data row17 col1" >510</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row18_col0" class="data row18 col0" >Sausage, Egg & Cheese McGriddles with Egg Whites</td>
#       <td id="T_990ca_row18_col1" class="data row18 col1" >500</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row19_col0" class="data row19 col0" >Sausage Biscuit (Large Biscuit)</td>
#       <td id="T_990ca_row19_col1" class="data row19 col1" >480</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row20_col0" class="data row20 col0" >Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)</td>
#       <td id="T_990ca_row20_col1" class="data row20 col1" >470</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row21_col0" class="data row21 col0" >Southern Style Chicken Biscuit (Large Biscuit)</td>
#       <td id="T_990ca_row21_col1" class="data row21 col1" >470</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row22_col0" class="data row22 col0" >Bacon, Egg & Cheese McGriddles</td>
#       <td id="T_990ca_row22_col1" class="data row22 col1" >460</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row23_col0" class="data row23 col0" >Cinnamon Melts</td>
#       <td id="T_990ca_row23_col1" class="data row23 col1" >460</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row24_col0" class="data row24 col0" >Sausage Biscuit with Egg Whites (Regular Biscuit)</td>
#       <td id="T_990ca_row24_col1" class="data row24 col1" >460</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row25_col0" class="data row25 col0" >Bacon, Egg & Cheese Biscuit (Regular Biscuit)</td>
#       <td id="T_990ca_row25_col1" class="data row25 col1" >460</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row26_col0" class="data row26 col0" >Sausage McMuffin with Egg</td>
#       <td id="T_990ca_row26_col1" class="data row26 col1" >450</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row27_col0" class="data row27 col0" >Sausage Biscuit (Regular Biscuit)</td>
#       <td id="T_990ca_row27_col1" class="data row27 col1" >430</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row28_col0" class="data row28 col0" >Steak & Egg McMuffin</td>
#       <td id="T_990ca_row28_col1" class="data row28 col1" >430</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row29_col0" class="data row29 col0" >Sausage McGriddles</td>
#       <td id="T_990ca_row29_col1" class="data row29 col1" >420</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row30_col0" class="data row30 col0" >Southern Style Chicken Biscuit (Regular Biscuit)</td>
#       <td id="T_990ca_row30_col1" class="data row30 col1" >410</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row31_col0" class="data row31 col0" >Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)</td>
#       <td id="T_990ca_row31_col1" class="data row31 col1" >410</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row32_col0" class="data row32 col0" >Bacon, Egg & Cheese McGriddles with Egg Whites</td>
#       <td id="T_990ca_row32_col1" class="data row32 col1" >400</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row33_col0" class="data row33 col0" >Sausage McMuffin with Egg Whites</td>
#       <td id="T_990ca_row33_col1" class="data row33 col1" >400</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row34_col0" class="data row34 col0" >Sausage McMuffin</td>
#       <td id="T_990ca_row34_col1" class="data row34 col1" >370</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row35_col0" class="data row35 col0" >Hotcakes</td>
#       <td id="T_990ca_row35_col1" class="data row35 col1" >350</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row36_col0" class="data row36 col0" >Sausage Burrito</td>
#       <td id="T_990ca_row36_col1" class="data row36 col1" >300</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row37_col0" class="data row37 col0" >Egg McMuffin</td>
#       <td id="T_990ca_row37_col1" class="data row37 col1" >300</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row38_col0" class="data row38 col0" >Fruit & Maple Oatmeal</td>
#       <td id="T_990ca_row38_col1" class="data row38 col1" >290</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row39_col0" class="data row39 col0" >Fruit & Maple Oatmeal without Brown Sugar</td>
#       <td id="T_990ca_row39_col1" class="data row39 col1" >260</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row40_col0" class="data row40 col0" >Egg White Delight</td>
#       <td id="T_990ca_row40_col1" class="data row40 col1" >250</td>
#     </tr>
#     <tr>
#       <td id="T_990ca_row41_col0" class="data row41 col0" >Hash Brown
# 3 . Smoothies & Shakes
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="af24c900-b969-4abe-a350-49fd3927d6b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af24c900-b969-4abe-a350-49fd3927d6b6")) {                    Plotly.newPlot(                        "af24c900-b969-4abe-a350-49fd3927d6b6",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=McFlurry with M&M’s Candies (Medium)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["McFlurry with M&M’s Candies (Medium)"],"legendgroup":"McFlurry with M&M’s Candies (Medium)","marker":{"color":"#636efa","size":[930],"sizemode":"area","sizeref":2.325,"symbol":"circle"},"mode":"markers","name":"McFlurry with M&M’s Candies (Medium)","orientation":"v","showlegend":true,"x":[33.0],"xaxis":"x","y":[930],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Strawberry Shake (Large)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Strawberry Shake (Large)"],"legendgroup":"Strawberry Shake (Large)","marker":{"color":"#EF553B","size":[850],"sizemode":"area","sizeref":2.325,"symbol":"circle"},"mode":"markers","name":"Strawberry Shake (Large)","orientation":"v","showlegend":true,"x":[24.0],"xaxis":"x","y":[850],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Chocolate Shake (Large)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Chocolate Shake (Large)"],"legendgroup":"Chocolate Shake (Large)","marker":{"color":"#00cc96","size":[850],"sizemode":"area","sizeref":2.325,"symbol":"circle"},"mode":"markers","name":"Chocolate Shake (Large)","orientation":"v","showlegend":true,"x":[23.0],"xaxis":"x","y":[850],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Vanilla Shake (Large)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Vanilla Shake (Large)"],"legendgroup":"Vanilla Shake (Large)","marker":{"color":"#ab63fa","size":[820],"sizemode":"area","sizeref":2.325,"symbol":"circle"},"mode":"markers","name":"Vanilla Shake (Large)","orientation":"v","showlegend":true,"x":[23.0],"xaxis":"x","y":[820],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Shamrock Shake (Large)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Shamrock Shake (Large)"],"legendgroup":"Shamrock Shake (Large)","marker":{"color":"#FFA15A","size":[820],"sizemode":"area","sizeref":2.325,"symbol":"circle"},"mode":"markers","name":"Shamrock Shake (Large)","orientation":"v","showlegend":true,"x":[23.0],"xaxis":"x","y":[820],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=McFlurry with Reese's Peanut Butter Cups (Medium)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["McFlurry with Reese's Peanut Butter Cups (Medium)"],"legendgroup":"McFlurry with Reese's Peanut Butter Cups (Medium)","marker":{"color":"#19d3f3","size":[810],"sizemode":"area","sizeref":2.325,"symbol":"circle"},"mode":"markers","name":"McFlurry with Reese's Peanut Butter Cups (Medium)","orientation":"v","showlegend":true,"x":[32.0],"xaxis":"x","y":[810],"yaxis":"y","type":"scatter"}, ...
# <style type="text/css">
# </style>
# <table id="T_9646f" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_9646f_level0_col0" class="col_heading level0 col0" >Item</th>
#       <th id="T_9646f_level0_col1" class="col_heading level0 col1" >Calories</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9646f_row0_col0" class="data row0 col0" >McFlurry with M&M’s Candies (Medium)</td>
#       <td id="T_9646f_row0_col1" class="data row0 col1" >930</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row1_col0" class="data row1 col0" >Strawberry Shake (Large)</td>
#       <td id="T_9646f_row1_col1" class="data row1 col1" >850</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row2_col0" class="data row2 col0" >Chocolate Shake (Large)</td>
#       <td id="T_9646f_row2_col1" class="data row2 col1" >850</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row3_col0" class="data row3 col0" >Vanilla Shake (Large)</td>
#       <td id="T_9646f_row3_col1" class="data row3 col1" >820</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row4_col0" class="data row4 col0" >Shamrock Shake (Large)</td>
#       <td id="T_9646f_row4_col1" class="data row4 col1" >820</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row5_col0" class="data row5 col0" >McFlurry with Reese's Peanut Butter Cups (Medium)</td>
#       <td id="T_9646f_row5_col1" class="data row5 col1" >810</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row6_col0" class="data row6 col0" >Chocolate Shake (Medium)</td>
#       <td id="T_9646f_row6_col1" class="data row6 col1" >700</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row7_col0" class="data row7 col0" >McFlurry with Oreo Cookies (Medium)</td>
#       <td id="T_9646f_row7_col1" class="data row7 col1" >690</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row8_col0" class="data row8 col0" >Strawberry Shake (Medium)</td>
#       <td id="T_9646f_row8_col1" class="data row8 col1" >690</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row9_col0" class="data row9 col0" >Vanilla Shake (Medium)</td>
#       <td id="T_9646f_row9_col1" class="data row9 col1" >660</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row10_col0" class="data row10 col0" >Shamrock Shake (Medium)</td>
#       <td id="T_9646f_row10_col1" class="data row10 col1" >660</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row11_col0" class="data row11 col0" >McFlurry with M&M’s Candies (Small)</td>
#       <td id="T_9646f_row11_col1" class="data row11 col1" >650</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row12_col0" class="data row12 col0" >Chocolate Shake (Small)</td>
#       <td id="T_9646f_row12_col1" class="data row12 col1" >560</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row13_col0" class="data row13 col0" >Strawberry Shake (Small)</td>
#       <td id="T_9646f_row13_col1" class="data row13 col1" >550</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row14_col0" class="data row14 col0" >Vanilla Shake (Small)</td>
#       <td id="T_9646f_row14_col1" class="data row14 col1" >530</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row15_col0" class="data row15 col0" >McFlurry with Oreo Cookies (Small)</td>
#       <td id="T_9646f_row15_col1" class="data row15 col1" >510</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row16_col0" class="data row16 col0" >McFlurry with M&M’s Candies (Snack)</td>
#       <td id="T_9646f_row16_col1" class="data row16 col1" >430</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row17_col0" class="data row17 col0" >McFlurry with Reese's Peanut Butter Cups (Snack)</td>
#       <td id="T_9646f_row17_col1" class="data row17 col1" >410</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row18_col0" class="data row18 col0" >Mango Pineapple Smoothie (Large)</td>
#       <td id="T_9646f_row18_col1" class="data row18 col1" >340</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row19_col0" class="data row19 col0" >McFlurry with Oreo Cookies (Snack)</td>
#       <td id="T_9646f_row19_col1" class="data row19 col1" >340</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row20_col0" class="data row20 col0" >Blueberry Pomegranate Smoothie (Large)</td>
#       <td id="T_9646f_row20_col1" class="data row20 col1" >340</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row21_col0" class="data row21 col0" >Strawberry Banana Smoothie (Large)</td>
#       <td id="T_9646f_row21_col1" class="data row21 col1" >330</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row22_col0" class="data row22 col0" >Blueberry Pomegranate Smoothie (Medium)</td>
#       <td id="T_9646f_row22_col1" class="data row22 col1" >260</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row23_col0" class="data row23 col0" >Mango Pineapple Smoothie (Medium)</td>
#       <td id="T_9646f_row23_col1" class="data row23 col1" >260</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row24_col0" class="data row24 col0" >Strawberry Banana Smoothie (Medium)</td>
#       <td id="T_9646f_row24_col1" class="data row24 col1" >250</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row25_col0" class="data row25 col0" >Blueberry Pomegranate Smoothie (Small)</td>
#       <td id="T_9646f_row25_col1" class="data row25 col1" >220</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row26_col0" class="data row26 col0" >Mango Pineapple Smoothie (Small)</td>
#       <td id="T_9646f_row26_col1" class="data row26 col1" >210</td>
#     </tr>
#     <tr>
#       <td id="T_9646f_row27_col0" class="data row27 col0" >Strawberry Banana Smoothie (Small)</td>
#       <td id="T_9646f_row27_col1" class="data row27 col1" >210</td>
#     </tr>
#   </tbody>
# </table>
# 4 . Beef & Pork
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="50c6e624-4538-48c1-9716-f579b35a0606" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50c6e624-4538-48c1-9716-f579b35a0606")) {                    Plotly.newPlot(                        "50c6e624-4538-48c1-9716-f579b35a0606",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Double Quarter Pounder with Cheese\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Double Quarter Pounder with Cheese"],"legendgroup":"Double Quarter Pounder with Cheese","marker":{"color":"#636efa","size":[750],"sizemode":"area","sizeref":1.875,"symbol":"circle"},"mode":"markers","name":"Double Quarter Pounder with Cheese","orientation":"v","showlegend":true,"x":[43.0],"xaxis":"x","y":[750],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Bacon Clubhouse Burger\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Bacon Clubhouse Burger"],"legendgroup":"Bacon Clubhouse Burger","marker":{"color":"#EF553B","size":[720],"sizemode":"area","sizeref":1.875,"symbol":"circle"},"mode":"markers","name":"Bacon Clubhouse Burger","orientation":"v","showlegend":true,"x":[40.0],"xaxis":"x","y":[720],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Quarter Pounder with Bacon Habanero Ranch\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Quarter Pounder with Bacon Habanero Ranch"],"legendgroup":"Quarter Pounder with Bacon Habanero Ranch","marker":{"color":"#00cc96","size":[610],"sizemode":"area","sizeref":1.875,"symbol":"circle"},"mode":"markers","name":"Quarter Pounder with Bacon Habanero Ranch","orientation":"v","showlegend":true,"x":[31.0],"xaxis":"x","y":[610],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Quarter Pounder with Bacon & Cheese\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Quarter Pounder with Bacon & Cheese"],"legendgroup":"Quarter Pounder with Bacon & Cheese","marker":{"color":"#ab63fa","size":[600],"sizemode":"area","sizeref":1.875,"symbol":"circle"},"mode":"markers","name":"Quarter Pounder with Bacon & Cheese","orientation":"v","showlegend":true,"x":[29.0],"xaxis":"x","y":[600],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Quarter Pounder Deluxe\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Quarter Pounder Deluxe"],"legendgroup":"Quarter Pounder Deluxe","marker":{"color":"#FFA15A","size":[540],"sizemode":"area","sizeref":1.875,"symbol":"circle"},"mode":"markers","name":"Quarter Pounder Deluxe","orientation":"v","showlegend":true,"x":[27.0],"xaxis":"x","y":[540],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Big Mac\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Big Mac"],"legendgroup":"Big Mac","marker":{"color":"#19d3f3","size":[530],"sizemode":"area","sizeref":1.875,"symbol":"circle"},"mode":"markers","name":"Big Mac","orientation":"v","showlegend":true,"x":[27.0],"xaxis":"x","y":[530],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb ...
# <style type="text/css">
# </style>
# <table id="T_af632" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_af632_level0_col0" class="col_heading level0 col0" >Item</th>
#       <th id="T_af632_level0_col1" class="col_heading level0 col1" >Calories</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_af632_row0_col0" class="data row0 col0" >Double Quarter Pounder with Cheese</td>
#       <td id="T_af632_row0_col1" class="data row0 col1" >750</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row1_col0" class="data row1 col0" >Bacon Clubhouse Burger</td>
#       <td id="T_af632_row1_col1" class="data row1 col1" >720</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row2_col0" class="data row2 col0" >Quarter Pounder with Bacon Habanero Ranch</td>
#       <td id="T_af632_row2_col1" class="data row2 col1" >610</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row3_col0" class="data row3 col0" >Quarter Pounder with Bacon & Cheese</td>
#       <td id="T_af632_row3_col1" class="data row3 col1" >600</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row4_col0" class="data row4 col0" >Quarter Pounder Deluxe</td>
#       <td id="T_af632_row4_col1" class="data row4 col1" >540</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row5_col0" class="data row5 col0" >Big Mac</td>
#       <td id="T_af632_row5_col1" class="data row5 col1" >530</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row6_col0" class="data row6 col0" >Quarter Pounder with Cheese</td>
#       <td id="T_af632_row6_col1" class="data row6 col1" >520</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row7_col0" class="data row7 col0" >McRib</td>
#       <td id="T_af632_row7_col1" class="data row7 col1" >500</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row8_col0" class="data row8 col0" >Bacon McDouble</td>
#       <td id="T_af632_row8_col1" class="data row8 col1" >440</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row9_col0" class="data row9 col0" >Double Cheeseburger</td>
#       <td id="T_af632_row9_col1" class="data row9 col1" >430</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row10_col0" class="data row10 col0" >Daily Double</td>
#       <td id="T_af632_row10_col1" class="data row10 col1" >430</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row11_col0" class="data row11 col0" >Jalapeño Double</td>
#       <td id="T_af632_row11_col1" class="data row11 col1" >430</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row12_col0" class="data row12 col0" >McDouble</td>
#       <td id="T_af632_row12_col1" class="data row12 col1" >380</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row13_col0" class="data row13 col0" >Cheeseburger</td>
#       <td id="T_af632_row13_col1" class="data row13 col1" >290</td>
#     </tr>
#     <tr>
#       <td id="T_af632_row14_col0" class="data row14 col0" >Hamburger</td>
#       <td id="T_af632_row14_col1" class="data row14 col1" >240</td>
#     </tr>
#   </tbody>
# </table>
# 5 . Snacks & Sides
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="91248176-52fb-4396-bd8a-6123e25afbad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91248176-52fb-4396-bd8a-6123e25afbad")) {                    Plotly.newPlot(                        "91248176-52fb-4396-bd8a-6123e25afbad",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Large French Fries\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Large French Fries"],"legendgroup":"Large French Fries","marker":{"color":"#636efa","size":[510],"sizemode":"area","sizeref":1.275,"symbol":"circle"},"mode":"markers","name":"Large French Fries","orientation":"v","showlegend":true,"x":[24.0],"xaxis":"x","y":[510],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Ranch Snack Wrap (Crispy Chicken)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Ranch Snack Wrap (Crispy Chicken)"],"legendgroup":"Ranch Snack Wrap (Crispy Chicken)","marker":{"color":"#EF553B","size":[360],"sizemode":"area","sizeref":1.275,"symbol":"circle"},"mode":"markers","name":"Ranch Snack Wrap (Crispy Chicken)","orientation":"v","showlegend":true,"x":[20.0],"xaxis":"x","y":[360],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Chipotle BBQ Snack Wrap (Crispy Chicken)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Chipotle BBQ Snack Wrap (Crispy Chicken)"],"legendgroup":"Chipotle BBQ Snack Wrap (Crispy Chicken)","marker":{"color":"#00cc96","size":[340],"sizemode":"area","sizeref":1.275,"symbol":"circle"},"mode":"markers","name":"Chipotle BBQ Snack Wrap (Crispy Chicken)","orientation":"v","showlegend":true,"x":[15.0],"xaxis":"x","y":[340],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Medium French Fries\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Medium French Fries"],"legendgroup":"Medium French Fries","marker":{"color":"#ab63fa","size":[340],"sizemode":"area","sizeref":1.275,"symbol":"circle"},"mode":"markers","name":"Medium French Fries","orientation":"v","showlegend":true,"x":[16.0],"xaxis":"x","y":[340],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Honey Mustard Snack Wrap (Crispy Chicken)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Honey Mustard Snack Wrap (Crispy Chicken)"],"legendgroup":"Honey Mustard Snack Wrap (Crispy Chicken)","marker":{"color":"#FFA15A","size":[330],"sizemode":"area","sizeref":1.275,"symbol":"circle"},"mode":"markers","name":"Honey Mustard Snack Wrap (Crispy Chicken)","orientation":"v","showlegend":true,"x":[15.0],"xaxis":"x","y":[330],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Ranch Snack Wrap (Grilled Chicken)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Ranch Snack Wrap (Grilled Chicken)"],"legendgroup":"Ranch Snack Wrap (Grilled Chicken)","marker":{"color":"#19d3f3","size":[280],"sizemode":"area","sizeref":1.275,"symbol":"circle"},"mode":"markers","name":"Ranch Snack Wrap (Grilled Chicken)","orientation":"v","showlegend":true,"x":[13.0],"xaxis":"x", ...
# <style type="text/css">
# </style>
# <table id="T_6fb56" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_6fb56_level0_col0" class="col_heading level0 col0" >Item</th>
#       <th id="T_6fb56_level0_col1" class="col_heading level0 col1" >Calories</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6fb56_row0_col0" class="data row0 col0" >Large French Fries</td>
#       <td id="T_6fb56_row0_col1" class="data row0 col1" >510</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row1_col0" class="data row1 col0" >Ranch Snack Wrap (Crispy Chicken)</td>
#       <td id="T_6fb56_row1_col1" class="data row1 col1" >360</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row2_col0" class="data row2 col0" >Chipotle BBQ Snack Wrap (Crispy Chicken)</td>
#       <td id="T_6fb56_row2_col1" class="data row2 col1" >340</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row3_col0" class="data row3 col0" >Medium French Fries</td>
#       <td id="T_6fb56_row3_col1" class="data row3 col1" >340</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row4_col0" class="data row4 col0" >Honey Mustard Snack Wrap (Crispy Chicken)</td>
#       <td id="T_6fb56_row4_col1" class="data row4 col1" >330</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row5_col0" class="data row5 col0" >Ranch Snack Wrap (Grilled Chicken)</td>
#       <td id="T_6fb56_row5_col1" class="data row5 col1" >280</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row6_col0" class="data row6 col0" >Chipotle BBQ Snack Wrap (Grilled Chicken)</td>
#       <td id="T_6fb56_row6_col1" class="data row6 col1" >260</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row7_col0" class="data row7 col0" >Honey Mustard Snack Wrap (Grilled Chicken)</td>
#       <td id="T_6fb56_row7_col1" class="data row7 col1" >250</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row8_col0" class="data row8 col0" >Small French Fries</td>
#       <td id="T_6fb56_row8_col1" class="data row8 col1" >230</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row9_col0" class="data row9 col0" >Fruit 'n Yogurt Parfait</td>
#       <td id="T_6fb56_row9_col1" class="data row9 col1" >150</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row10_col0" class="data row10 col0" >Kids French Fries</td>
#       <td id="T_6fb56_row10_col1" class="data row10 col1" >110</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row11_col0" class="data row11 col0" >Side Salad</td>
#       <td id="T_6fb56_row11_col1" class="data row11 col1" >20</td>
#     </tr>
#     <tr>
#       <td id="T_6fb56_row12_col0" class="data row12 col0" >Apple Slices</td>
#       <td id="T_6fb56_row12_col1" class="data row12 col1" >15</td>
#     </tr>
#   </tbody>
# </table>
# 6 . Desserts
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e3113417-431b-4fa9-ba64-7026979697e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3113417-431b-4fa9-ba64-7026979697e6")) {                    Plotly.newPlot(                        "e3113417-431b-4fa9-ba64-7026979697e6",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Hot Caramel Sundae\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Hot Caramel Sundae"],"legendgroup":"Hot Caramel Sundae","marker":{"color":"#636efa","size":[340],"sizemode":"area","sizeref":0.85,"symbol":"circle"},"mode":"markers","name":"Hot Caramel Sundae","orientation":"v","showlegend":true,"x":[8.0],"xaxis":"x","y":[340],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Hot Fudge Sundae\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Hot Fudge Sundae"],"legendgroup":"Hot Fudge Sundae","marker":{"color":"#EF553B","size":[330],"sizemode":"area","sizeref":0.85,"symbol":"circle"},"mode":"markers","name":"Hot Fudge Sundae","orientation":"v","showlegend":true,"x":[9.0],"xaxis":"x","y":[330],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Strawberry Sundae\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Strawberry Sundae"],"legendgroup":"Strawberry Sundae","marker":{"color":"#00cc96","size":[280],"sizemode":"area","sizeref":0.85,"symbol":"circle"},"mode":"markers","name":"Strawberry Sundae","orientation":"v","showlegend":true,"x":[6.0],"xaxis":"x","y":[280],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Baked Apple Pie\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Baked Apple Pie"],"legendgroup":"Baked Apple Pie","marker":{"color":"#ab63fa","size":[250],"sizemode":"area","sizeref":0.85,"symbol":"circle"},"mode":"markers","name":"Baked Apple Pie","orientation":"v","showlegend":true,"x":[13.0],"xaxis":"x","y":[250],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Chocolate Chip Cookie\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Chocolate Chip Cookie"],"legendgroup":"Chocolate Chip Cookie","marker":{"color":"#FFA15A","size":[160],"sizemode":"area","sizeref":0.85,"symbol":"circle"},"mode":"markers","name":"Chocolate Chip Cookie","orientation":"v","showlegend":true,"x":[8.0],"xaxis":"x","y":[160],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Oatmeal Raisin Cookie\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Oatmeal Raisin Cookie"],"legendgroup":"Oatmeal Raisin Cookie","marker":{"color":"#19d3f3","size":[150],"sizemode":"area","sizeref":0.85,"symbol":"circle"},"mode":"markers","name":"Oatmeal Raisin Cookie","orientation":"v","showlegend":true,"x":[6.0],"xaxis":"x","y":[150],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Kids Ice Cream Cone\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Kids Ice Cream Cone"],"legendgroup":"Kids Ic ...
# <style type="text/css">
# </style>
# <table id="T_29193" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_29193_level0_col0" class="col_heading level0 col0" >Item</th>
#       <th id="T_29193_level0_col1" class="col_heading level0 col1" >Calories</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_29193_row0_col0" class="data row0 col0" >Hot Caramel Sundae</td>
#       <td id="T_29193_row0_col1" class="data row0 col1" >340</td>
#     </tr>
#     <tr>
#       <td id="T_29193_row1_col0" class="data row1 col0" >Hot Fudge Sundae</td>
#       <td id="T_29193_row1_col1" class="data row1 col1" >330</td>
#     </tr>
#     <tr>
#       <td id="T_29193_row2_col0" class="data row2 col0" >Strawberry Sundae</td>
#       <td id="T_29193_row2_col1" class="data row2 col1" >280</td>
#     </tr>
#     <tr>
#       <td id="T_29193_row3_col0" class="data row3 col0" >Baked Apple Pie</td>
#       <td id="T_29193_row3_col1" class="data row3 col1" >250</td>
#     </tr>
#     <tr>
#       <td id="T_29193_row4_col0" class="data row4 col0" >Chocolate Chip Cookie</td>
#       <td id="T_29193_row4_col1" class="data row4 col1" >160</td>
#     </tr>
#     <tr>
#       <td id="T_29193_row5_col0" class="data row5 col0" >Oatmeal Raisin Cookie</td>
#       <td id="T_29193_row5_col1" class="data row5 col1" >150</td>
#     </tr>
#     <tr>
#       <td id="T_29193_row6_col0" class="data row6 col0" >Kids Ice Cream Cone</td>
#       <td id="T_29193_row6_col1" class="data row6 col1" >45</td>
#     </tr>
#   </tbody>
# </table>
# 7 . Beverages
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c2eeb087-203c-4a2e-aada-a70799049b8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2eeb087-203c-4a2e-aada-a70799049b8f")) {                    Plotly.newPlot(                        "c2eeb087-203c-4a2e-aada-a70799049b8f",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Sprite (Large)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Sprite (Large)"],"legendgroup":"Sprite (Large)","marker":{"color":"#636efa","size":[280],"sizemode":"area","sizeref":0.7,"symbol":"circle"},"mode":"markers","name":"Sprite (Large)","orientation":"v","showlegend":true,"x":[0.0],"xaxis":"x","y":[280],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Coca-Cola Classic (Large)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Coca-Cola Classic (Large)"],"legendgroup":"Coca-Cola Classic (Large)","marker":{"color":"#EF553B","size":[280],"sizemode":"area","sizeref":0.7,"symbol":"circle"},"mode":"markers","name":"Coca-Cola Classic (Large)","orientation":"v","showlegend":true,"x":[0.0],"xaxis":"x","y":[280],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Minute Maid Orange Juice (Large)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Minute Maid Orange Juice (Large)"],"legendgroup":"Minute Maid Orange Juice (Large)","marker":{"color":"#00cc96","size":[280],"sizemode":"area","sizeref":0.7,"symbol":"circle"},"mode":"markers","name":"Minute Maid Orange Juice (Large)","orientation":"v","showlegend":true,"x":[0.0],"xaxis":"x","y":[280],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Dr Pepper (Large)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Dr Pepper (Large)"],"legendgroup":"Dr Pepper (Large)","marker":{"color":"#ab63fa","size":[270],"sizemode":"area","sizeref":0.7,"symbol":"circle"},"mode":"markers","name":"Dr Pepper (Large)","orientation":"v","showlegend":true,"x":[0.0],"xaxis":"x","y":[270],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Sprite (Medium)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Sprite (Medium)"],"legendgroup":"Sprite (Medium)","marker":{"color":"#FFA15A","size":[200],"sizemode":"area","sizeref":0.7,"symbol":"circle"},"mode":"markers","name":"Sprite (Medium)","orientation":"v","showlegend":true,"x":[0.0],"xaxis":"x","y":[200],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Coca-Cola Classic (Medium)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Coca-Cola Classic (Medium)"],"legendgroup":"Coca-Cola Classic (Medium)","marker":{"color":"#19d3f3","size":[200],"sizemode":"area","sizeref":0.7,"symbol":"circle"},"mode":"markers","name":"Coca-Cola Classic (Medium)","orientation":"v","showlegend":true,"x":[0.0],"xaxis":"x","y":[200],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eItem=Dr Pepper (Medium)\u003cbr\u003eTotal Fat=%{x}\u003cbr\u003eCalories=%{marker.size}\u003cextra\u003e\u003c\ ...
# <style type="text/css">
# </style>
# <table id="T_41ad0" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_41ad0_level0_col0" class="col_heading level0 col0" >Item</th>
#       <th id="T_41ad0_level0_col1" class="col_heading level0 col1" >Calories</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_41ad0_row0_col0" class="data row0 col0" >Sprite (Large)</td>
#       <td id="T_41ad0_row0_col1" class="data row0 col1" >280</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row1_col0" class="data row1 col0" >Minute Maid Orange Juice (Large)</td>
#       <td id="T_41ad0_row1_col1" class="data row1 col1" >280</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row2_col0" class="data row2 col0" >Coca-Cola Classic (Large)</td>
#       <td id="T_41ad0_row2_col1" class="data row2 col1" >280</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row3_col0" class="data row3 col0" >Dr Pepper (Large)</td>
#       <td id="T_41ad0_row3_col1" class="data row3 col1" >270</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row4_col0" class="data row4 col0" >Sprite (Medium)</td>
#       <td id="T_41ad0_row4_col1" class="data row4 col1" >200</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row5_col0" class="data row5 col0" >Coca-Cola Classic (Medium)</td>
#       <td id="T_41ad0_row5_col1" class="data row5 col1" >200</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row6_col0" class="data row6 col0" >Dr Pepper (Medium)</td>
#       <td id="T_41ad0_row6_col1" class="data row6 col1" >190</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row7_col0" class="data row7 col0" >Minute Maid Orange Juice (Medium)</td>
#       <td id="T_41ad0_row7_col1" class="data row7 col1" >190</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row8_col0" class="data row8 col0" >Minute Maid Orange Juice (Small)</td>
#       <td id="T_41ad0_row8_col1" class="data row8 col1" >150</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row9_col0" class="data row9 col0" >Dr Pepper (Small)</td>
#       <td id="T_41ad0_row9_col1" class="data row9 col1" >140</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row10_col0" class="data row10 col0" >Sprite (Small)</td>
#       <td id="T_41ad0_row10_col1" class="data row10 col1" >140</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row11_col0" class="data row11 col0" >Coca-Cola Classic (Small)</td>
#       <td id="T_41ad0_row11_col1" class="data row11 col1" >140</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row12_col0" class="data row12 col0" >Fat Free Chocolate Milk Jug</td>
#       <td id="T_41ad0_row12_col1" class="data row12 col1" >130</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row13_col0" class="data row13 col0" >1% Low Fat Milk Jug</td>
#       <td id="T_41ad0_row13_col1" class="data row13 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row14_col0" class="data row14 col0" >Sprite (Child)</td>
#       <td id="T_41ad0_row14_col1" class="data row14 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row15_col0" class="data row15 col0" >Dr Pepper (Child)</td>
#       <td id="T_41ad0_row15_col1" class="data row15 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row16_col0" class="data row16 col0" >Coca-Cola Classic (Child)</td>
#       <td id="T_41ad0_row16_col1" class="data row16 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row17_col0" class="data row17 col0" >Minute Maid 100% Apple Juice Box</td>
#       <td id="T_41ad0_row17_col1" class="data row17 col1" >80</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row18_col0" class="data row18 col0" >Diet Dr Pepper (Medium)</td>
#       <td id="T_41ad0_row18_col1" class="data row18 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row19_col0" class="data row19 col0" >Diet Dr Pepper (Child)</td>
#       <td id="T_41ad0_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row20_col0" class="data row20 col0" >Diet Dr Pepper (Large)</td>
#       <td id="T_41ad0_row20_col1" class="data row20 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row21_col0" class="data row21 col0" >Diet Dr Pepper (Small)</td>
#       <td id="T_41ad0_row21_col1" class="data row21 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row22_col0" class="data row22 col0" >Diet Coke (Child)</td>
#       <td id="T_41ad0_row22_col1" class="data row22 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row23_col0" class="data row23 col0" >Diet Coke (Large)</td>
#       <td id="T_41ad0_row23_col1" class="data row23 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row24_col0" class="data row24 col0" >Diet Coke (Medium)</td>
#       <td id="T_41ad0_row24_col1" class="data row24 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row25_col0" class="data row25 col0" >Diet Coke (Small)</td>
#       <td id="T_41ad0_row25_col1" class="data row25 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_41ad0_row26_col0" class="data row26 col0" >Dasani Water Bottle</td>
#       <td id="T_41ad0_row26_col1" class="data row26 col1" >0</td>
#     </tr>
#   </tbody>
# </table>
